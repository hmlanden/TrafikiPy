# %%
#===========DEPENDENCIES=============
import matplotlib as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns
import requests

pd.set_option('display.max_columns', None)

# %%
#============IMPORT==============
csv_file_path = os.path.join('Resources', 'accidents_2014.csv')
traffic_df = pd.read_csv(csv_file_path)
traffic_df
# Out:
#       Accident_Index  Longitude   Latitude  Police_Force  Accident_Severity  \
# 0      201401BS70001  -0.206443  51.496345             1                  3
# 1      201401BS70006  -0.171308  51.495892             1                  3
# 2      201401BS70009  -0.201326  51.498245             1                  3
# 3      201401BS70011  -0.207445  51.507511             1                  3
# 4      201401BS70013  -0.179731  51.497822             1                  3
# 5      201401BS70014  -0.165585  51.498501             1                  2
# 6      201401BS70015  -0.184189  51.501668             1                  3
# 7      201401BS70039  -0.183017  51.494905             1                  3
# 8      201401BS70043  -0.207908  51.514083             1                  3
# 9      201401BS70045  -0.184189  51.501668             1                  3
# 10     201401BS70046  -0.194121  51.494627             1                  3
# ...

# %%
#============DROP BLANK COLUMNS===========

traffic_df.dropna(
    axis=1,
    how='all',
    inplace=True
)

#============DROP BLANK ROWS WITH BLANK VALUES==========

traffic_df['Junction_Control'].replace(
    np.nan, 'None', inplace=True)

traffic_df.replace(
    '', np.nan, inplace=True)

traffic_df.replace(
    'Unknown', np.nan, inplace=True)

traffic_df.dropna(axis=0, inplace=True)

#===========REPLACING ERRANT/MISPELLED VALUES===============

traffic_df['Light_Conditions'].replace(
    'Darkeness: No street lighting',
    'Darkness: No street lighting', 
    inplace=True
)

traffic_df['Pedestrian_Crossing-Physical_Facilities'].replace(
    'non-junction pedestrian crossing',
    'Non-junction Pedestrian Crossing', 
    inplace=True
)

#===========RENAMING COLUMNS===============

traffic_df.rename(columns=
    {'Accident_Index' : 'Accident Index',
     'Longitude' : 'Longitude', 
     'Latitude' : 'Latitude', 
     'Police_Force' : 'Police Force', 
     'Accident_Severity' : 'Accident Severity', 
     'Number_of_Vehicles' : 'Number of Vehicles', 
     'Number_of_Casualties' : 'Number of Casualties', 
     'Date' : 'Date', 
     'Day_of_Week' : 'Day of Week', 
     'Time' : 'Time', 
     'Local_Authority_(District)' : 'Local Authority District', 
     'Local_Authority_(Highway)' : 'Local Authority Highway', 
     '1st_Road_Class' : '1st Road Class', 
     '1st_Road_Number' : '1st Road Number', 
     'Road_Type' : 'Road Type', 
     'Speed_limit' : 'Speed Limit', 
     'Junction_Control' : 'Junction Control', 
     '2nd_Road_Class' : '2nd Road Class', 
     '2nd_Road_Number' : '2nd Road Number', 
     'Pedestrian_Crossing-Human_Control' : 'Pedestrian Crossing Human Control', 
     'Pedestrian_Crossing-Physical_Facilities' : 'Pedestrian Crossing Physical Facilities', 
     'Light_Conditions' : 'Light Conditions', 
     'Weather_Conditions' : 'Weather Conditions', 
     'Road_Surface_Conditions' : 'Road Surface Conditions', 
     'Special_Conditions_at_Site' : 'Special Conditions at Site', 
     'Carriageway_Hazards' : 'Carriageway Hazards', 
     'Urban_or_Rural_Area' : 'Urban or Rural Area', 
     'Did_Police_Officer_Attend_Scene_of_Accident' : 'Police Attended Scene of Accident', 
     'LSOA_of_Accident_Location' : 'LSOA of Accident Location', 
     'Year' : 'Year', 
    })
# Out:
#       Accident Index  Longitude   Latitude  Police Force  Accident Severity  \
# 0      201401BS70001  -0.206443  51.496345             1                  3
# 1      201401BS70006  -0.171308  51.495892             1                  3
# 2      201401BS70009  -0.201326  51.498245             1                  3
# 3      201401BS70011  -0.207445  51.507511             1                  3
# 4      201401BS70013  -0.179731  51.497822             1                  3
# 5      201401BS70014  -0.165585  51.498501             1                  2
# 7      201401BS70039  -0.183017  51.494905             1                  3
# 8      201401BS70043  -0.207908  51.514083             1                  3
# 9      201401BS70045  -0.184189  51.501668             1                  3
# 10     201401BS70046  -0.194121  51.494627             1                  3
# 11     201401BS70047  -0.189938  51.502026             1                  3
# ...

# %%
weather_condition = traffic_df['Weather_Conditions']
accident_severity = traffic_df['Accident_Severity']
number_of_casualities = traffic_df['Number_of_Casualties']

temp_weather_severity_df = pd.DataFrame({'Weather':weather_condition,'Severity':accident_severity})
temp_weather_severity_df.head()
# Out:
#    Severity                     Weather
# 0         3  Raining without high winds
# 1         3     Fine without high winds
# 2         3     Fine without high winds
# 3         3     Fine without high winds
# 4         3  Raining without high winds

# %%
final_weather_severity_df = temp_weather_severity_df.groupby(by='Severity',as_index=False).count()
final_weather_severity_df
# Out:
#    Severity  Weather
# 0         1      554
# 1         2     7537
# 2         3    46056

# %%
plt = sns.barplot(final_weather_severity_df['Severity'],final_weather_severity_df['Weather'])

# %%
final_weather_severity_df = temp_weather_severity_df.groupby(by='Weather',as_index=False).count()
final_weather_severity_df
# Out:
#                       Weather  Severity
# 0        Fine with high winds       720
# 1     Fine without high winds     44418
# 2                 Fog or mist       145
# 3                       Other       853
# 4     Raining with high winds      1203
# 5  Raining without high winds      6724
# 6     Snowing with high winds        24
# 7  Snowing without high winds        60

# %%
plt = sns.barplot(final_weather_severity_df['Severity'],final_weather_severity_df['Weather'])
plt.set(xlabel='Number of Accidents')
# Out:
# [Text(0.5,0,'Number of Accidents')]

# %%
X = traffic_df[['Accident_Severity','Number_of_Casualties']]
Y = traffic_df['Road_Surface_Conditions']
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X, Y)
print(clf.predict([[4, 6]]))
# Out:
# ['Snow']

# %%
# b = temp_weather_severity_df.groupby(by= temp_weather_severity_df['Weather'],as_index=False)
# final_weather_severity_df = temp_weather_severity_df.groupby(by=['Severity','Weather'],as_index=False)
# weather_severity_df = pd.DataFrame(final_weather_severity_df.sum())
# weather_severity_df
# plt = sns.barplot(weather_severity_df['Severity'],weather_severity_df['Weather'])
# temp_weather_severity_df['Weather'].value_counts()
# temp_weather_severity_df['Severity'].sum()
